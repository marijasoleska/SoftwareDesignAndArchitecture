# %%
import os
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
from threading import Thread

# %%
def format_date(date):
    return date.strftime("%m/%d/%Y")

def init_directory():
    if not os.path.exists('./data'):
        os.makedirs('./data')

BASE_URL = 'https://www.mse.mk/en/stats/symbolhistory/'
init_directory()

# %%
def fetch_companies():
    sample_url = 'https://www.mse.mk/en/stats/symbolhistory/KMB'
    response = requests.get(sample_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    company_names = soup.select('.form-control option')
    
    valid_company_names = [name.text for name in company_names if not any(char.isdigit() for char in name.text)]
    return valid_company_names

companies = fetch_companies()
companies
# Out:
# ['ADIN',
#  'ALK',
#  'ALKB',
#  'AMBR',
#  'AMEH',
#  'APTK',
#  'ATPP',
#  'AUMK',
#  'BANA',
#  'BGOR',
#  'BIKF',
#  'BIM',
#  'BLTU',
#  'CBNG',
#  'CDHV',
#  'CEVI',
#  'CKB',
#  'CKBKO',
#  'DEBA',
#  'DIMI',
#  'EDST',
#  'ELMA',
#  'ELNC',
#  'ENER',
#  'ENSA',
#  'EUHA',
#  'EUMK',
#  'EVRO',
#  'FAKM',
#  'FERS',
#  'FKTL',
#  'FROT',
#  'FUBT',
#  'GALE',
#  'GDKM',
#  'GECK',
#  'GECT',
#  'GIMS',
#  'GRDN',
#  'GRNT',
#  'GRSN',
#  'GRZD',
#  'GTC',
#  'GTRG',
#  'IJUG',
#  'INB',
#  'INHO',
#  'INOV',
#  'INPR',
#  'INTP',
#  'JAKO',
#  'JUSK',
#  'KARO',
#  'KDFO',
#  'KJUBI',
#  'KKST',
#  'KLST',
#  'KMB',
#  'KMPR',
#  'KOMU',
#  'KONF',
#  'KONZ',
#  'KORZ',
#  'KPSS',
#  'KULT',
#  'KVAS',
#  'LAJO',
#  'LHND',
#  'LOTO',
#  'LOZP',
#  'MAGP',
#  'MAKP',
#  'MAKS',
#  'MB',
#  'MERM',
#  'MKSD',
#  'MLKR',
#  'MODA',
#  'MPOL',
#  'MPT',
#  'MPTE',
#  'MTUR',
#  'MZHE',
#  'MZPU',
#  'NEME',
#  'NOSK',
#  'OBPP',
#  'OILK',
#  'OKTA',
#  'OMOS',
#  'OPFO',
#  'OPTK',
#  'ORAN',
#  'OSPO',
#  'OTEK',
#  'PELK',
#  'PGGV',
#  'PKB',
#  'POPK',
#  'PPIV',
#  'PROD',
#  'PROT',
#  'PTRS',
#  'RADE',
#  'REPL',
#  'RIMI',
#  'RINS',
#  'RZEK',
#  'RZIT',
#  'RZIZ',
#  'RZLE',
#  'RZLV',
#  'RZTK',
#  'RZUG',
#  'RZUS',
#  'SBT',
#  'SDOM',
#  'SIL',
#  'SKON',
#  'SKP',
#  'SLAV',
#  'SNBT',
#  'SNBTO',
#  'SOLN',
#  'SPAZ',
#  'SPAZP',
#  'SPOL',
#  'SSPR',
#  'STB',
#  'STBP',
#  'STIL',
#  'STOK',
#  'TAJM',
#  'TBKO',
#  'TEAL',
#  'TEHN',
#  'TEL',
#  'TETE',
#  'TIKV',
#  'TKPR',
#  'TKVS',
#  'TNB',
#  'TRDB',
#  'TRPS',
#  'TRUB',
#  'TSMP',
#  'TSZS',
#  'TTK',
#  'TTKO',
#  'UNI',
#  'USJE',
#  'VARG',
#  'VFPM',
#  'VITA',
#  'VROS',
#  'VSC',
#  'VTKS',
#  'ZAS',
#  'ZILU',
#  'ZILUP',
#  'ZIMS',
#  'ZKAR',
#  'ZPKO',
#  'ZPOG',
#  'ZUAS']

# %%
def parse_cells(row):
    cells = row.find_all('td')
    
    def format_price(value):
        try:
            return "{:,.2f}".format(float(value.replace(',', '.'))).replace(',', 'X').replace('.', ',').replace('X', '.')
        except ValueError:
            return value
    
    item = {
        'Date': cells[0].text,
        'Last trade price': format_price(cells[1].text),
        'Max': format_price(cells[2].text),
        'Min': format_price(cells[3].text),
        'Avg Price': format_price(cells[4].text),
        '%chg.': cells[5].text.replace('.', ','),
        'Volume': cells[6].text,
        'TurnoverBEST_MKD': format_price(cells[7].text),
        'TotalTurnoverMKD': format_price(cells[8].text)
    }
    
    return item

# %%
def scrape_data_from_url(company, date_from, date_to):
    url = f"{BASE_URL}{company}?FromDate={date_from}&ToDate={date_to}" 
    response = requests.get(url, timeout=(25, 60))
    
    if response.status_code != 200:
        print(f"Failed to fetch data for {company} from {date_from} to {date_to}")
        return pd.DataFrame() 

    soup = BeautifulSoup(response.text, 'html.parser')
    rows = soup.find_all('tbody')[0].find_all('tr') if soup.find_all('tbody') else []
    data = [parse_cells(row) for row in rows]
    
    df = pd.DataFrame(data)
    return df

# %%
def fetch_data_for_company(company, years_back=10):
    today = datetime.today()
    end_date = format_date(today)
    start_date = format_date(today - timedelta(days=365 * years_back))
    
    company_data = []
    for year in range(years_back):
        date_to = format_date(today - timedelta(days=365 * year))
        date_from = format_date(today - timedelta(days=365 * (year + 1)))
        
        yearly_data = scrape_data_from_url(company, date_from, date_to)
        if not yearly_data.empty:
            company_data.append(yearly_data)
    
    if company_data:
        final_df = pd.concat(company_data, ignore_index=True)
        final_df.to_csv(f'./data/{company}.csv', index=False)
        print(f"Data for {company} saved to ./data/{company}.csv")
    else:
        print(f"No data collected for {company}")

fetch_data_for_company("TEL")
# Out:
# Data for TEL saved to ./data/TEL.csv

# %%
def fetch_data_for_all_companies(years_back=10):
    start_time = time.time()  
    for company in companies:
        print(f"Fetching data for {company}")
        fetch_data_for_company(company, years_back=years_back)
    end_time = time.time()  
    elapsed_time = end_time - start_time 
    print(f"Total time taken to fetch data: {elapsed_time / 60:.2f} minutes")

fetch_data_for_all_companies()
# Out:
# Fetching data for ADIN
# Data for ADIN saved to ./data/ADIN.csv
# Fetching data for ALK
# Data for ALK saved to ./data/ALK.csv
# Fetching data for ALKB
# Data for ALKB saved to ./data/ALKB.csv
# Fetching data for AMBR
# Data for AMBR saved to ./data/AMBR.csv
# Fetching data for AMEH
# Data for AMEH saved to ./data/AMEH.csv
# Fetching data for APTK
# Data for APTK saved to ./data/APTK.csv
# Fetching data for ATPP
# Data for ATPP saved to ./data/ATPP.csv
# Fetching data for AUMK
# Data for AUMK saved to ./data/AUMK.csv
# Fetching data for BANA
# Data for BANA saved to ./data/BANA.csv
# Fetching data for BGOR
# Data for BGOR saved to ./data/BGOR.csv
# Fetching data for BIKF
# Data for BIKF saved to ./data/BIKF.csv
# Fetching data for BIM
# Data for BIM saved to ./data/BIM.csv
# Fetching data for BLTU
# Data for BLTU saved to ./data/BLTU.csv
# Fetching data for CBNG
# Data for CBNG saved to ./data/CBNG.csv
# Fetching data for CDHV
# Data for CDHV saved to ./data/CDHV.csv
# Fetching data for CEVI
# Data for CEVI saved to ./data/CEVI.csv
# Fetching data for CKB
# Data for CKB saved to ./data/CKB.csv
# Fetching data for CKBKO
# Data for CKBKO saved to ./data/CKBKO.csv
# Fetching data for DEBA
# Data for DEBA saved to ./data/DEBA.csv
# Fetching data for DIMI
# Data for DIMI saved to ./data/DIMI.csv
# Fetching data for EDST
# Data for EDST saved to ./data/EDST.csv
# Fetching data for ELMA
# Data for ELMA saved to ./data/ELMA.csv
# Fetching data for ELNC
# Data for ELNC saved to ./data/ELNC.csv
# Fetching data for ENER
# Data for ENER saved to ./data/ENER.csv
# Fetching data for ENSA
# Data for ENSA saved to ./data/ENSA.csv
# Fetching data for EUHA
# Data for EUHA saved to ./data/EUHA.csv
# Fetching data for EUMK
# Data for EUMK saved to ./data/EUMK.csv
# Fetching data for EVRO
# Data for EVRO saved to ./data/EVRO.csv
# Fetching data for FAKM
# Data for FAKM saved to ./data/FAKM.csv
# Fetching data for FERS
# Data for FERS saved to ./data/FERS.csv
# Fetching data for FKTL
# Data for FKTL saved to ./data/FKTL.csv
# Fetching data for FROT
# Failed to fetch data for FROT from 11/17/2014 to 11/17/2015
# Data for FROT saved to ./data/FROT.csv
# Fetching data for FUBT
# Data for FUBT saved to ./data/FUBT.csv
# Fetching data for GALE
# Failed to fetch data for GALE from 11/15/2023 to 11/14/2024
# Failed to fetch data for GALE from 11/15/2021 to 11/15/2022
# Failed to fetch data for GALE from 11/15/2020 to 11/15/2021
# Failed to fetch data for GALE from 11/16/2019 to 11/15/2020
# Failed to fetch data for GALE from 11/16/2018 to 11/16/2019
# Failed to fetch data for GALE from 11/16/2016 to 11/16/2017
# Failed to fetch data for GALE from 11/17/2015 to 11/16/2016
# Failed to fetch data for GALE from 11/17/2014 to 11/17/2015
# Data for GALE saved to ./data/GALE.csv
# Fetching data for GDKM
# Failed to fetch data for GDKM from 11/15/2023 to 11/14/2024
# Failed to fetch data for GDKM from 11/15/2022 to 11/15/2023
# Failed to fetch data for GDKM from 11/15/2021 to 11/15/2022
# Failed to fetch data for GDKM from 11/15/2020 to 11/15/2021
# Failed to fetch data for GDKM from 11/16/2017 to 11/16/2018
# Failed to fetch data for GDKM from 11/16/2016 to 11/16/2017
# Data for GDKM saved to ./data/GDKM.csv
# Fetching data for GECK
# Failed to fetch data for GECK from 11/15/2023 to 11/14/2024
# Failed to fetch data for GECK from 11/16/2016 to 11/16/2017
# Data for GECK saved to ./data/GECK.csv
# Fetching data for GECT
# Failed to fetch data for GECT from 11/17/2015 to 11/16/2016
# Failed to fetch data for GECT from 11/17/2014 to 11/17/2015
# Data for GECT saved to ./data/GECT.csv
# Fetching data for GIMS
# Failed to fetch data for GIMS from 11/15/2022 to 11/15/2023
# Failed to fetch data for GIMS from 11/15/2020 to 11/15/2021
# Failed to fetch data for GIMS from 11/16/2019 to 11/15/2020
# Failed to fetch data for GIMS from 11/16/2018 to 11/16/2019
# Failed to fetch data for GIMS from 11/16/2017 to 11/16/2018
# Failed to fetch data for GIMS from 11/16/2016 to 11/16/2017
# Failed to fetch data for GIMS from 11/17/2015 to 11/16/2016
# Failed to fetch data for GIMS from 11/17/2014 to 11/17/2015
# Data for GIMS saved to ./data/GIMS.csv
# Fetching data for GRDN
# Failed to fetch data for GRDN from 11/15/2023 to 11/14/2024
# Failed to fetch data for GRDN from 11/16/2016 to 11/16/2017
# Data for GRDN saved to ./data/GRDN.csv
# Fetching data for GRNT
# Data for GRNT saved to ./data/GRNT.csv
# Fetching data for GRSN
# Failed to fetch data for GRSN from 11/16/2017 to 11/16/2018
# Data for GRSN saved to ./data/GRSN.csv
# Fetching data for GRZD
# Data for GRZD saved to ./data/GRZD.csv
# Fetching data for GTC
# Data for GTC saved to ./data/GTC.csv
# Fetching data for GTRG
# Data for GTRG saved to ./data/GTRG.csv
# Fetching data for IJUG
# Data for IJUG saved to ./data/IJUG.csv
# Fetching data for INB
# Data for INB saved to ./data/INB.csv
# Fetching data for INHO
# Data for INHO saved to ./data/INHO.csv
# Fetching data for INOV
# Data for INOV saved to ./data/INOV.csv
# Fetching data for INPR
# Data for INPR saved to ./data/INPR.csv
# Fetching data for INTP
# Data for INTP saved to ./data/INTP.csv
# Fetching data for JAKO
# Data for JAKO saved to ./data/JAKO.csv
# Fetching data for JUSK
# Data for JUSK saved to ./data/JUSK.csv
# Fetching data for KARO
# Data for KARO saved to ./data/KARO.csv
# Fetching data for KDFO
# Failed to fetch data for KDFO from 11/16/2019 to 11/15/2020
# Failed to fetch data for KDFO from 11/16/2018 to 11/16/2019
# Failed to fetch data for KDFO from 11/16/2017 to 11/16/2018
# Failed to fetch data for KDFO from 11/16/2016 to 11/16/2017
# Failed to fetch data for KDFO from 11/17/2015 to 11/16/2016
# Failed to fetch data for KDFO from 11/17/2014 to 11/17/2015
# Data for KDFO saved to ./data/KDFO.csv
# Fetching data for KJUBI
# Failed to fetch data for KJUBI from 11/15/2023 to 11/14/2024
# Failed to fetch data for KJUBI from 11/15/2022 to 11/15/2023
# Failed to fetch data for KJUBI from 11/15/2021 to 11/15/2022
# Failed to fetch data for KJUBI from 11/15/2020 to 11/15/2021
# Data for KJUBI saved to ./data/KJUBI.csv
# Fetching data for KKST
# Failed to fetch data for KKST from 11/15/2023 to 11/14/2024
# Failed to fetch data for KKST from 11/15/2020 to 11/15/2021
# Data for KKST saved to ./data/KKST.csv
# Fetching data for KLST
# Failed to fetch data for KLST from 11/16/2016 to 11/16/2017
# Failed to fetch data for KLST from 11/17/2015 to 11/16/2016
# Failed to fetch data for KLST from 11/17/2014 to 11/17/2015
# Data for KLST saved to ./data/KLST.csv
# Fetching data for KMB
# Failed to fetch data for KMB from 11/16/2016 to 11/16/2017
# Failed to fetch data for KMB from 11/17/2015 to 11/16/2016
# Failed to fetch data for KMB from 11/17/2014 to 11/17/2015
# Data for KMB saved to ./data/KMB.csv
# Fetching data for KMPR
# Failed to fetch data for KMPR from 11/15/2021 to 11/15/2022
# Failed to fetch data for KMPR from 11/15/2020 to 11/15/2021
# Failed to fetch data for KMPR from 11/16/2019 to 11/15/2020
# Failed to fetch data for KMPR from 11/16/2018 to 11/16/2019
# Failed to fetch data for KMPR from 11/16/2016 to 11/16/2017
# Failed to fetch data for KMPR from 11/17/2015 to 11/16/2016
# Failed to fetch data for KMPR from 11/17/2014 to 11/17/2015
# Data for KMPR saved to ./data/KMPR.csv
# Fetching data for KOMU
# Failed to fetch data for KOMU from 11/15/2023 to 11/14/2024
# Failed to fetch data for KOMU from 11/15/2022 to 11/15/2023
# Failed to fetch data for KOMU from 11/15/2021 to 11/15/2022
# Failed to fetch data for KOMU from 11/16/2019 to 11/15/2020
# Failed to fetch data for KOMU from 11/16/2018 to 11/16/2019
# Failed to fetch data for KOMU from 11/17/2015 to 11/16/2016
# Failed to fetch data for KOMU from 11/17/2014 to 11/17/2015
# Data for KOMU saved to ./data/KOMU.csv
# Fetching data for KONF
# Data for KONF saved to ./data/KONF.csv
# Fetching data for KONZ
# Failed to fetch data for KONZ from 11/15/2023 to 11/14/2024
# Failed to fetch data for KONZ from 11/15/2022 to 11/15/2023
# Failed to fetch data for KONZ from 11/15/2021 to 11/15/2022
# Failed to fetch data for KONZ from 11/15/2020 to 11/15/2021
# Failed to fetch data for KONZ from 11/16/2019 to 11/15/2020
# Failed to fetch data for KONZ from 11/16/2018 to 11/16/2019
# Failed to fetch data for KONZ from 11/16/2017 to 11/16/2018
# Failed to fetch data for KONZ from 11/16/2016 to 11/16/2017
# Failed to fetch data for KONZ from 11/17/2015 to 11/16/2016
# Failed to fetch data for KONZ from 11/17/2014 to 11/17/2015
# No data collected for KONZ
# Fetching data for KORZ
# Failed to fetch data for KORZ from 11/15/2023 to 11/14/2024
# Failed to fetch data for KORZ from 11/15/2022 to 11/15/2023
# Failed to fetch data for KORZ from 11/15/2021 to 11/15/2022
# Failed to fetch data for KORZ from 11/15/2020 to 11/15/2021
# Failed to fetch data for KORZ from 11/16/2019 to 11/15/2020
# Failed to fetch data for KORZ from 11/16/2018 to 11/16/2019
# Failed to fetch data for KORZ from 11/16/2017 to 11/16/2018
# Data for KORZ saved to ./data/KORZ.csv
# Fetching data for KPSS
# Data for KPSS saved to ./data/KPSS.csv
# Fetching data for KULT
# Data for KULT saved to ./data/KULT.csv
# Fetching data for KVAS
# Data for KVAS saved to ./data/KVAS.csv
# Fetching data for LAJO
# Data for LAJO saved to ./data/LAJO.csv
# Fetching data for LHND
# Data for LHND saved to ./data/LHND.csv
# Fetching data for LOTO
# Data for LOTO saved to ./data/LOTO.csv
# Fetching data for LOZP
# Data for LOZP saved to ./data/LOZP.csv
# Fetching data for MAGP
# Failed to fetch data for MAGP from 11/15/2023 to 11/14/2024
# Failed to fetch data for MAGP from 11/15/2022 to 11/15/2023
# Failed to fetch data for MAGP from 11/15/2021 to 11/15/2022
# Failed to fetch data for MAGP from 11/15/2020 to 11/15/2021
# Failed to fetch data for MAGP from 11/16/2019 to 11/15/2020
# Data for MAGP saved to ./data/MAGP.csv
# Fetching data for MAKP
# Data for MAKP saved to ./data/MAKP.csv
# Fetching data for MAKS
# Data for MAKS saved to ./data/MAKS.csv
# Fetching data for MB
# Failed to fetch data for MB from 11/17/2014 to 11/17/2015
# Data for MB saved to ./data/MB.csv
# Fetching data for MERM
# Failed to fetch data for MERM from 11/16/2018 to 11/16/2019
# Failed to fetch data for MERM from 11/16/2017 to 11/16/2018
# Failed to fetch data for MERM from 11/16/2016 to 11/16/2017
# Failed to fetch data for MERM from 11/17/2015 to 11/16/2016
# Data for MERM saved to ./data/MERM.csv
# Fetching data for MKSD
# Failed to fetch data for MKSD from 11/15/2023 to 11/14/2024
# Failed to fetch data for MKSD from 11/15/2022 to 11/15/2023
# Failed to fetch data for MKSD from 11/15/2021 to 11/15/2022
# Failed to fetch data for MKSD from 11/15/2020 to 11/15/2021
# Failed to fetch data for MKSD from 11/16/2019 to 11/15/2020
# Failed to fetch data for MKSD from 11/16/2018 to 11/16/2019
# Data for MKSD saved to ./data/MKSD.csv
# Fetching data for MLKR
# Data for MLKR saved to ./data/MLKR.csv
# Fetching data for MODA
# Data for MODA saved to ./data/MODA.csv
# Fetching data for MPOL
# Failed to fetch data for MPOL from 11/16/2018 to 11/16/2019
# Failed to fetch data for MPOL from 11/17/2015 to 11/16/2016
# Data for MPOL saved to ./data/MPOL.csv
# Fetching data for MPT
# Failed to fetch data for MPT from 11/15/2021 to 11/15/2022
# Failed to fetch data for MPT from 11/15/2020 to 11/15/2021
# Failed to fetch data for MPT from 11/16/2019 to 11/15/2020
# Failed to fetch data for MPT from 11/16/2018 to 11/16/2019
# Failed to fetch data for MPT from 11/16/2017 to 11/16/2018
# Failed to fetch data for MPT from 11/16/2016 to 11/16/2017
# Data for MPT saved to ./data/MPT.csv
# Fetching data for MPTE
# Data for MPTE saved to ./data/MPTE.csv
# Fetching data for MTUR
# Failed to fetch data for MTUR from 11/15/2020 to 11/15/2021
# Failed to fetch data for MTUR from 11/16/2019 to 11/15/2020
# Failed to fetch data for MTUR from 11/16/2018 to 11/16/2019
# Failed to fetch data for MTUR from 11/16/2017 to 11/16/2018
# Data for MTUR saved to ./data/MTUR.csv
# Fetching data for MZHE
# Data for MZHE saved to ./data/MZHE.csv
# Fetching data for MZPU
# Failed to fetch data for MZPU from 11/15/2023 to 11/14/2024
# Failed to fetch data for MZPU from 11/15/2022 to 11/15/2023
# Failed to fetch data for MZPU from 11/15/2021 to 11/15/2022
# Failed to fetch data for MZPU from 11/15/2020 to 11/15/2021
# Failed to fetch data for MZPU from 11/16/2019 to 11/15/2020
# Failed to fetch data for MZPU from 11/16/2018 to 11/16/2019
# Failed to fetch data for MZPU from 11/16/2017 to 11/16/2018
# Data for MZPU saved to ./data/MZPU.csv
# Fetching data for NEME
# Failed to fetch data for NEME from 11/15/2020 to 11/15/2021
# Failed to fetch data for NEME from 11/16/2019 to 11/15/2020
# Failed to fetch data for NEME from 11/16/2018 to 11/16/2019
# Failed to fetch data for NEME from 11/16/2017 to 11/16/2018
# Failed to fetch data for NEME from 11/16/2016 to 11/16/2017
# Data for NEME saved to ./data/NEME.csv
# Fetching data for NOSK
# Data for NOSK saved to ./data/NOSK.csv
# Fetching data for OBPP
# Data for OBPP saved to ./data/OBPP.csv
# Fetching data for OILK
# Data for OILK saved to ./data/OILK.csv
# Fetching data for OKTA
# Data for OKTA saved to ./data/OKTA.csv
# Fetching data for OMOS
# Data for OMOS saved to ./data/OMOS.csv
# Fetching data for OPFO
# Data for OPFO saved to ./data/OPFO.csv
# Fetching data for OPTK
# Data for OPTK saved to ./data/OPTK.csv
# Fetching data for ORAN
# Data for ORAN saved to ./data/ORAN.csv
# Fetching data for OSPO
# Data for OSPO saved to ./data/OSPO.csv
# Fetching data for OTEK
# Data for OTEK saved to ./data/OTEK.csv
# Fetching data for PELK
# Data for PELK saved to ./data/PELK.csv
# Fetching data for PGGV
# Failed to fetch data for PGGV from 11/17/2015 to 11/16/2016
# Data for PGGV saved to ./data/PGGV.csv
# Fetching data for PKB
# Failed to fetch data for PKB from 11/15/2023 to 11/14/2024
# Failed to fetch data for PKB from 11/15/2022 to 11/15/2023
# Failed to fetch data for PKB from 11/16/2017 to 11/16/2018
# Data for PKB saved to ./data/PKB.csv
# Fetching data for POPK
# Failed to fetch data for POPK from 11/15/2022 to 11/15/2023
# Failed to fetch data for POPK from 11/15/2021 to 11/15/2022
# Failed to fetch data for POPK from 11/15/2020 to 11/15/2021
# Failed to fetch data for POPK from 11/16/2018 to 11/16/2019
# Failed to fetch data for POPK from 11/16/2017 to 11/16/2018
# Failed to fetch data for POPK from 11/16/2016 to 11/16/2017
# Failed to fetch data for POPK from 11/17/2015 to 11/16/2016
# Data for POPK saved to ./data/POPK.csv
# Fetching data for PPIV
# Failed to fetch data for PPIV from 11/16/2019 to 11/15/2020
# Failed to fetch data for PPIV from 11/16/2018 to 11/16/2019
# Data for PPIV saved to ./data/PPIV.csv
# Fetching data for PROD
# Data for PROD saved to ./data/PROD.csv
# Fetching data for PROT
# Data for PROT saved to ./data/PROT.csv
# Fetching data for PTRS
# Data for PTRS saved to ./data/PTRS.csv
# Fetching data for RADE
# Data for RADE saved to ./data/RADE.csv
# Fetching data for REPL
# Data for REPL saved to ./data/REPL.csv
# Fetching data for RIMI
# Data for RIMI saved to ./data/RIMI.csv
# Fetching data for RINS
# Data for RINS saved to ./data/RINS.csv
# Fetching data for RZEK
# Data for RZEK saved to ./data/RZEK.csv
# Fetching data for RZIT
# Data for RZIT saved to ./data/RZIT.csv
# Fetching data for RZIZ
# Data for RZIZ saved to ./data/RZIZ.csv
# Fetching data for RZLE
# Data for RZLE saved to ./data/RZLE.csv
# Fetching data for RZLV
# Data for RZLV saved to ./data/RZLV.csv
# Fetching data for RZTK
# Data for RZTK saved to ./data/RZTK.csv
# Fetching data for RZUG
# Data for RZUG saved to ./data/RZUG.csv
# Fetching data for RZUS
# Data for RZUS saved to ./data/RZUS.csv
# Fetching data for SBT
# Data for SBT saved to ./data/SBT.csv
# Fetching data for SDOM
# Data for SDOM saved to ./data/SDOM.csv
# Fetching data for SIL
# Data for SIL saved to ./data/SIL.csv
# Fetching data for SKON
# Data for SKON saved to ./data/SKON.csv
# Fetching data for SKP
# Data for SKP saved to ./data/SKP.csv
# Fetching data for SLAV
# Data for SLAV saved to ./data/SLAV.csv
# Fetching data for SNBT
# Data for SNBT saved to ./data/SNBT.csv
# Fetching data for SNBTO
# Data for SNBTO saved to ./data/SNBTO.csv
# Fetching data for SOLN
# Data for SOLN saved to ./data/SOLN.csv
# Fetching data for SPAZ
# Data for SPAZ saved to ./data/SPAZ.csv
# Fetching data for SPAZP
# Data for SPAZP saved to ./data/SPAZP.csv
# Fetching data for SPOL
# Data for SPOL saved to ./data/SPOL.csv
# Fetching data for SSPR
# Data for SSPR saved to ./data/SSPR.csv
# Fetching data for STB
# Data for STB saved to ./data/STB.csv
# Fetching data for STBP
# Data for STBP saved to ./data/STBP.csv
# Fetching data for STIL
# Data for STIL saved to ./data/STIL.csv
# Fetching data for STOK
# Data for STOK saved to ./data/STOK.csv
# Fetching data for TAJM
# Data for TAJM saved to ./data/TAJM.csv
# Fetching data for TBKO
# Data for TBKO saved to ./data/TBKO.csv
# Fetching data for TEAL
# Data for TEAL saved to ./data/TEAL.csv
# Fetching data for TEHN
# Data for TEHN saved to ./data/TEHN.csv
# Fetching data for TEL
# Data for TEL saved to ./data/TEL.csv
# Fetching data for TETE
# Data for TETE saved to ./data/TETE.csv
# Fetching data for TIKV
# Data for TIKV saved to ./data/TIKV.csv
# Fetching data for TKPR
# Data for TKPR saved to ./data/TKPR.csv
# Fetching data for TKVS
# Data for TKVS saved to ./data/TKVS.csv
# Fetching data for TNB
# Data for TNB saved to ./data/TNB.csv
# Fetching data for TRDB
# Data for TRDB saved to ./data/TRDB.csv
# Fetching data for TRPS
# Data for TRPS saved to ./data/TRPS.csv
# Fetching data for TRUB
# Data for TRUB saved to ./data/TRUB.csv
# Fetching data for TSMP
# Data for TSMP saved to ./data/TSMP.csv
# Fetching data for TSZS
# Data for TSZS saved to ./data/TSZS.csv
# Fetching data for TTK
# Data for TTK saved to ./data/TTK.csv
# Fetching data for TTKO
# Data for TTKO saved to ./data/TTKO.csv
# Fetching data for UNI
# Data for UNI saved to ./data/UNI.csv
# Fetching data for USJE
# Data for USJE saved to ./data/USJE.csv
# Fetching data for VARG
# Data for VARG saved to ./data/VARG.csv
# Fetching data for VFPM
# Data for VFPM saved to ./data/VFPM.csv
# Fetching data for VITA
# Data for VITA saved to ./data/VITA.csv
# Fetching data for VROS
# Data for VROS saved to ./data/VROS.csv
# Fetching data for VSC
# Data for VSC saved to ./data/VSC.csv
# Fetching data for VTKS
# Data for VTKS saved to ./data/VTKS.csv
# Fetching data for ZAS
# Data for ZAS saved to ./data/ZAS.csv
# Fetching data for ZILU
# Data for ZILU saved to ./data/ZILU.csv
# Fetching data for ZILUP
# Data for ZILUP saved to ./data/ZILUP.csv
# Fetching data for ZIMS
# Data for ZIMS saved to ./data/ZIMS.csv
# Fetching data for ZKAR
# Data for ZKAR saved to ./data/ZKAR.csv
# Fetching data for ZPKO
# Data for ZPKO saved to ./data/ZPKO.csv
# Fetching data for ZPOG
# Data for ZPOG saved to ./data/ZPOG.csv
# Fetching data for ZUAS
# Data for ZUAS saved to ./data/ZUAS.csv
# Total time taken to fetch data: 11.06 minutes
